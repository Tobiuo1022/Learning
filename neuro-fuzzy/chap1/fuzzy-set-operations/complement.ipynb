# %%
import skfuzzy as sk
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_qual = np.arange(0, 11, 1)

qual_lo = sk.trimf(x_qual, [0, 0, 5])

tri_not = sk.fuzzy_not(qual_lo)

# %%
plt.plot(x_qual, qual_lo)
plt.plot(x_qual, tri_not)
