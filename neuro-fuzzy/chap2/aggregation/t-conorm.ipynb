# %%
import numpy as np
import skfuzzy as sk
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 関数を定義する

# %%
def t_conorm(mfx, mfy):
    tnorm = np.fmax(mfx, mfy)
    return tnorm

# %%
x = np.arange(0, 80, 0.1)

full_speed = sk.sigmf(x, 80, 2)
slow = sk.sigmf(x, 30, 2)

tnorm = t_conorm(full_speed, slow)

# %%
plt.plot(x, tnorm)

# %% [markdown]
# ## 3次元でplotしてみる

# %%
X, Y = np.meshgrid(full_speed, slow)
tnorm3D = t_conorm(X, Y)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.set_xlabel("full speed")
ax.set_ylabel("slow")
ax.view_init(azim=-120)
ax.plot_surface(X, Y, tnorm3D)
cs = ax.contourf(X,Y,tnorm3D,100, cmap="RdBu")
plt.colorbar(cs)
